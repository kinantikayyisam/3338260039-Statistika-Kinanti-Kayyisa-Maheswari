# %%
def cek_ganjil_genap(angka):
    # Operator % digunakan untuk mencari sisa hasil bagi
    if angka % 2 == 0:
        return "genap"
    else:
        return "ganjil"

# %%
cek_ganjil_genap(178)
# Out:
# 'genap'

# %%
cek_ganjil_genap(67)
# Out:
# 'ganjil'

# %%
cek_ganjil_genap(1718)
# Out:
# 'genap'
